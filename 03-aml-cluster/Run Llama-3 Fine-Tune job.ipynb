# %% [markdown]
# # Fine-Tuning Llama 3 Using Azure Machine Learning Jobs and Hugging Face Tools

# %% [markdown]
# ## Introduction
#
# In this lab we will build upon the knowledge gained in the previous lab, where you fine-tuned Llama 3 inside a notebook.  For that lab, we used an interactive Jupyter notebook with one (possibly small) GPU to perform development.
#
# In this lab we'll run the same code using an Azure ML _job_, which can be run asynchronously as well as scheduled to run at a specific time.  We will also use an AML _cluster_ which can contain multiple machines with multiple GPUs each.  This is an ideal approach for fine-tuning large LLMs and/or training for many epochs.
#
# ## Prerequisites
# To run this lab you need to have the following:
#
# * An AML single-machine compute cluster named `mycluster`
# * An AML `environment` named `finetune_llama3@latest` and containing the same libraries as the ones in the `requirements.txt` file
# * The [Medical Dialogs](https://huggingface.co/datasets/ruslanmv/ai-medical-chatbot) dataset, loaded into AML's Data Repository, accessible through the Assets->Data link on the left-hand side of the screen, with the name MedicalDialogs.
# * The code fine named `fine_tune_llama3_doctor.py` which is a slightly modified, single-file version of the code in the previous lab
#
# ## Tools Used
# The Python tools used in this lab are the following open-source Hugging Face tools:
#
# * [Transformers](https://huggingface.co/docs/transformers/v4.17.0/en/index) - Implementation of a number of deep-learning models using the Transformer architecture
# * [PEFT](https://huggingface.co/docs/peft/index) - Implementation of Parameter-Efficient Fine-Tuning, which allows the fine-tuning of pretrained models using only a small subset of their parameters.  We will be using the Quantized LORA (QLORA) algorithm for fine-tuning a model that was quantized to use 4 bits for each weight instead of 16 bits.
# * [TRL](https://huggingface.co/docs/trl/index) - This library contains a number of algorithms that help train Transformer-based language models using Reinforcement Learning.  As our dataset contains medical questions and answers, we will be using the Supervised Fine-Tuning (SFT) algorithm.
# * [Accelerate](https://huggingface.co/docs/accelerate/index) - This library makes it easy to run multi-gpu training and is integrated into the other libraries we will use.
# * [BitsAndBytes](https://huggingface.co/docs/bitsandbytes/index) - This library provides tools for loading models in a quantized form for PyTorch.
#
# We will also use the built-in [MLFlow](https://mlflow.org/docs/latest/tracking.html) capabilites in AML to track metrics and outputs from our job.

# %% [markdown]
# ## Imports & Definitions
#
# In this section we import the required libraries for running the job.  Note that for this notebook we only use the AML SDK and a pre-configured Jupyter kernel that comes with AML.  The actual training code has been moved into `fine_tune_llama_3_doctor.py` with the addition of a `main` function and the ability to accept training parameters.

# %%
# AML SDK imports

from azure.ai.ml import MLClient, Input, Output, command
from azure.identity import DefaultAzureCredential
from azure.ai.ml.entities import JobResourceConfiguration
from utils.amlauth import AuthHelper
from dotenv import load_dotenv

# Authentication
# credential = DefaultAzureCredential()
load_dotenv(dotenv_path=".env", override=True)

from utils.amlauth import AuthHelper
settings = AuthHelper.load_settings()
credential = AuthHelper.test_credential()

# %%
# AML Details - These are available by clicking the down-arrow on the top right-hand sign of the screen, next to 
# your login initials

# SUBSCRIPTION="<Your Subscription ID>"
# RESOURCE_GROUP="<AML Studio Resource Group Name>"
# WS_NAME="<Workspace Name>"

SUBSCRIPTION=settings.subscription_id
RESOURCE_GROUP=settings.resource_group_name
WS_NAME=settings.workspace_name

# Get a handle to the workspace - this handle allows you to send commands to the workspace via code
ml_client = MLClient(
    credential=credential,
    subscription_id=SUBSCRIPTION,
    resource_group_name=RESOURCE_GROUP,
    workspace_name=WS_NAME
)

# %%
models = ml_client.models.list()
for model in models:
    print(model.name)
# Out:
# general-aml-gbdnh
# azureml_3decdba7-5bd1-47e8-a14f-acc4daafdd2c_output_mlflow_model_folder
# bert-base-uncased-emotion
# azureml_d26d8445-f3ba-406a-8836-797b1e39058b_output_mlflow_model_folder
# bert-base-uncased-emotion-detection
# azureml_9ae80173-e780-4249-be80-66732b81648a_output_mlflow_model_folder
# azureml_b9f9ebfa-68dd-47ac-8ae5-0d12c5d2b766_output_mlflow_model_folder
# azureml_bb6af235-f056-4e2f-ad8d-e474ff06fff2_output_mlflow_model_folder

# %% [markdown]
# ## Submitting the Job
#
# In this section we submit the job for processing using the AML SDK.
#
# Some interesting points in this `command` object:
# *  We submit the entire directory in the AML notebook to the job
# *  We use Hugging Face's `accelerate` tool to automatically use all of the GPU's available on the compute cluster
# *  We define and submit a `batch_size` parameter, that will be handled in the `fine_tune_llama_3_doctor.py` file

# %%
# Declare a command object with the details of the job
job = command(

    # local path where the code is stored - in this case, we want the entire directory in the AML notebook 
    code=".",  

    # Using HuggingFace tools to request ALL GPUs on the machine
    command="python download_files.py && accelerate launch fine_tune_llama_3_doctor.py " + \
        "--num_epochs=${{inputs.num_epochs}} --batch_size=${{inputs.batch_size}} --num_data_rows=${{inputs.num_data_rows}}",

    # Pass a custom parameter to the training script
    inputs={
        "batch_size": 8,
        "num_epochs": 2,
        "num_data_rows": 10000,
    },

    # Name of environment to use
    # environment="finetune_llama3@latest",
    environment="tf-torch-transformer@2",

    # Display name of this experiment in the Jobs display (MLFlow)
    display_name="Fine-Tune Llama 3",

    # Name of compute cluster
    # compute="mycluster",
    compute="gpu-cluster",

    # Directory (on host) where to save HF models
    resources=JobResourceConfiguration(docker_args="-v=/mnt:/mounts"),
)

# %%
# Run and return status for the command object
returned_job = ml_client.create_or_update(job)
# Out:
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Run and return status for the command object
# ----> 2 returned_job = ml_client.create_or_update(job)
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_ml_client.py:1272, in MLClient.create_or_update(self, entity, **kwargs)
#    1256 def create_or_update(
#    1257     self,
#    1258     entity: T,
#    1259     **kwargs,
#    1260 ) -> T:
#    1261     """Creates or updates an Azure ML resource.
#    1262
#    1263     :param entity: The resource to create or update.
#    (...)   1269         , ~azure.ai.ml.entities.Environment, ~azure.ai.ml.entities.Component, ~azure.ai.ml.entities.Datastore]
#    1270     """
# -> 1272     return _create_or_update(entity, self._operation_container.all_operations, **kwargs)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\functools.py:912, in singledispatch.<locals>.wrapper(*args, **kw)
#     908 if not args:
#     909     raise TypeError(f'{funcname} requires at least '
#     910                     '1 positional argument')
# --> 912 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_ml_client.py:1331, in _(entity, operations, **kwargs)
#    1328 @_create_or_update.register(Job)
#    1329 def _(entity: Job, operations, **kwargs):
#    1330     module_logger.debug("Creating or updating job")
# -> 1331     return operations[AzureMLResourceType.JOB].create_or_update(entity, **kwargs)
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_telemetry\activity.py:371, in monitor_with_telemetry_mixin.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     369 dimensions = {**parameter_dimensions, **(custom_dimensions or {})}
#     370 with log_activity(logger, activity_name or f.__name__, activity_type, dimensions) as activityLogger:
# --> 371     return_value = f(*args, **kwargs)
#     372     if not parameter_dimensions:
#     373         # collect from return if no dimensions from parameter
#     374         activityLogger.activity_info.update(_collect_from_return_value(return_value))
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_job_operations.py:680, in JobOperations.create_or_update(self, job, description, compute, tags, experiment_name, skip_validation, **kwargs)
#     677         self._validate(job, raise_on_failure=True)
#     679     # Create all dependent resources
# --> 680     self._resolve_arm_id_or_upload_dependencies(job)
#     681 except (ValidationException, ValidationError) as ex:
#     682     log_and_raise_error(ex)
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_job_operations.py:1137, in JobOperations._resolve_arm_id_or_upload_dependencies(self, job)
#    1127 def _resolve_arm_id_or_upload_dependencies(self, job: Job) -> None:
#    1128     """This method converts name or name:version to ARM id. Or it
#    1129     registers/uploads nested dependencies.
#    1130
#    (...)   1134     :rtype: Job
#    1135     """
# -> 1137     self._resolve_arm_id_or_azureml_id(job, self._orchestrators.get_asset_arm_id)
#    1139     if isinstance(job, PipelineJob):
#    1140         # Resolve top-level inputs
#    1141         self._resolve_job_inputs(self._flatten_group_inputs(job.inputs), job._base_path)
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_job_operations.py:1416, in JobOperations._resolve_arm_id_or_azureml_id(self, job, resolver)
#    1414     job.compute = self._resolve_compute_id(resolver, job.compute)
#    1415 elif isinstance(job, Command):
# -> 1416     job = self._resolve_arm_id_for_command_job(job, resolver)
#    1417 elif isinstance(job, ImportJob):
#    1418     job = self._resolve_arm_id_for_import_job(job, resolver)
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_job_operations.py:1466, in JobOperations._resolve_arm_id_for_command_job(self, job, resolver)
#    1457     raise ValidationException(
#    1458         message=msg.format(job.code),
#    1459         target=ErrorTarget.JOB,
#    (...)   1462         error_type=ValidationErrorType.INVALID_VALUE,
#    1463     )
#    1465 if job.code is not None and not is_ARM_id_for_resource(job.code, AzureMLResourceType.CODE):
# -> 1466     job.code = resolver(  # type: ignore
#    1467         Code(base_path=job._base_path, path=job.code),
#    1468         azureml_type=AzureMLResourceType.CODE,
#    1469     )
#    1470 job.environment = resolver(job.environment, azureml_type=AzureMLResourceType.ENVIRONMENT)
#    1471 job.compute = self._resolve_compute_id(resolver, job.compute)
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_operation_orchestrator.py:238, in OperationOrchestrator.get_asset_arm_id(self, asset, azureml_type, register_asset, sub_workspace_resource)
#     236 # TODO: once the asset redesign is finished, this logic can be replaced with unified API
#     237 if azureml_type == AzureMLResourceType.CODE and isinstance(asset, Code):
# --> 238     result = self._get_code_asset_arm_id(asset, register_asset=register_asset)
#     239 elif azureml_type == AzureMLResourceType.ENVIRONMENT and isinstance(asset, Environment):
#     240     result = self._get_environment_arm_id(asset, register_asset=register_asset)
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_operation_orchestrator.py:304, in OperationOrchestrator._get_code_asset_arm_id(self, code_asset, register_asset)
#     302     return uploaded_code_asset
#     303 except (MlException, HttpResponseError) as e:
# --> 304     raise e
#     305 except Exception as e:
#     306     raise AssetException(
#     307         message=f"Error with code: {e}",
#     308         target=ErrorTarget.ASSET,
#    (...)    311         error_category=ErrorCategory.SYSTEM_ERROR,
#     312     ) from e
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_operation_orchestrator.py:279, in OperationOrchestrator._get_code_asset_arm_id(self, code_asset, register_asset)
#     277 self._validate_datastore_name(code_asset.path)
#     278 if register_asset:
# --> 279     code_asset = self._code_assets.create_or_update(code_asset)  # type: ignore[attr-defined]
#     280     return str(code_asset.id)
#     281 sas_info = get_storage_info_for_non_registry_asset(
#     282     service_client=self._code_assets._service_client,  # type: ignore[attr-defined]
#     283     workspace_name=self._operation_scope.workspace_name,
#    (...)    286     resource_group=self._operation_scope.resource_group_name,
#     287 )
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_telemetry\activity.py:288, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     284     with tracer.start_as_current_span(ACTIVITY_SPAN):
#     285         with log_activity(
#     286             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     287         ):
# --> 288             return f(*args, **kwargs)
#     289 elif hasattr(logger, "package_logger"):
#     290     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_code_operations.py:212, in CodeOperations.create_or_update(self, code)
#     205     if str(ex) == ASSET_PATH_ERROR:
#     206         raise AssetPathException(
#     207             message=CHANGED_ASSET_PATH_MSG,
#     208             target=ErrorTarget.CODE,
#     209             no_personal_data_message=CHANGED_ASSET_PATH_MSG_NO_PERSONAL_DATA,
#     210             error_category=ErrorCategory.USER_ERROR,
#     211         ) from ex
# --> 212 raise ex
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\operations\_code_operations.py:160, in CodeOperations.create_or_update(self, code)
#     157         sas_uri = sas_info["sas_uri"]
#     158         blob_uri = sas_info["blob_uri"]
# --> 160 code, _ = _check_and_upload_path(
#     161     artifact=code,
#     162     asset_operations=self,
#     163     sas_uri=sas_uri,
#     164     artifact_type=ErrorTarget.CODE,
#     165     show_progress=self._show_progress,
#     166     blob_uri=blob_uri,
#     167 )
#     169 # For anonymous code, if the code already exists in storage, we reuse the name,
#     170 # version stored in the storage metadata so the same anonymous code won't be created again.
#     171 if code._is_anonymous:
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_artifacts\_artifact_utilities.py:511, in _check_and_upload_path(artifact, asset_operations, artifact_type, datastore_name, sas_uri, show_progress, blob_uri)
#     509 if not path.is_absolute():
#     510     path = Path(artifact.base_path, path).resolve()
# --> 511 uploaded_artifact = _upload_to_datastore(
#     512     asset_operations._operation_scope,
#     513     asset_operations._datastore_operation,
#     514     path,
#     515     datastore_name=datastore_name,
#     516     asset_name=artifact.name,
#     517     asset_version=str(artifact.version),
#     518     asset_hash=getattr(artifact, "_upload_hash", None),
#     519     sas_uri=sas_uri,
#     520     artifact_type=artifact_type,
#     521     show_progress=show_progress,
#     522     ignore_file=getattr(artifact, "_ignore_file", None),
#     523     blob_uri=blob_uri,
#     524 )
#     525 indicator_file = uploaded_artifact.indicator_file  # reference to storage contents
#     526 if artifact._is_anonymous:
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_artifacts\_artifact_utilities.py:389, in _upload_to_datastore(operation_scope, datastore_operation, path, artifact_type, datastore_name, show_progress, asset_name, asset_version, asset_hash, ignore_file, sas_uri, blob_uri)
#     387 if not asset_hash:
#     388     asset_hash = get_object_hash(path, ignore_file)
# --> 389 artifact = upload_artifact(
#     390     str(path),
#     391     datastore_operation,
#     392     operation_scope,
#     393     datastore_name,
#     394     show_progress=show_progress,
#     395     asset_hash=asset_hash,
#     396     asset_name=asset_name,
#     397     asset_version=asset_version,
#     398     ignore_file=ignore_file,
#     399     sas_uri=sas_uri,
#     400 )
#     401 if blob_uri:
#     402     artifact.storage_account_url = blob_uri
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_artifacts\_artifact_utilities.py:248, in upload_artifact(local_path, datastore_operation, operation_scope, datastore_name, asset_hash, show_progress, asset_name, asset_version, ignore_file, sas_uri)
#     245     datastore_info = get_datastore_info(datastore_operation, datastore_name)
#     246     storage_client = get_storage_client(**datastore_info)
# --> 248 artifact_info = storage_client.upload(
#     249     local_path,
#     250     asset_hash=asset_hash,
#     251     show_progress=show_progress,
#     252     name=asset_name,
#     253     version=asset_version,
#     254     ignore_file=ignore_file,
#     255 )
#     257 artifact = ArtifactStorageInfo(
#     258     name=artifact_info["name"],
#     259     version=artifact_info["version"],
#    (...)    267     is_file=Path(local_path).is_file(),
#     268 )
#     269 return artifact
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_artifacts\_blob_storage_helper.py:122, in BlobStorageClient.upload(self, source, name, version, ignore_file, asset_hash, show_progress)
#     120 # start upload
#     121 if os.path.isdir(source):
# --> 122     upload_directory(
#     123         storage_client=self,
#     124         source=source,
#     125         dest=asset_id,
#     126         msg=msg,
#     127         show_progress=show_progress,
#     128         ignore_file=ignore_file,
#     129     )
#     130 else:
#     131     self.indicator_file = dest
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_utils\_asset_utils.py:697, in upload_directory(storage_client, source, dest, msg, show_progress, ignore_file)
#     689 if (
#     690     type(storage_client).__name__ == BLOB_STORAGE_CLIENT_NAME
#     691 ):  # Only for Gen2StorageClient, Blob Storage doesn't have true directories
#    (...)    694     # file in the directory is designated as the file where the confirmation metadata
#     695     # will be added at the end of the upload.
#     696     storage_client.indicator_file = upload_paths[0][1]
# --> 697     storage_client.check_blob_exists()
#     699 # Submit paths to workers for upload
#     700 num_cores = int(cpu_count()) * PROCESSES_PER_CORE
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_artifacts\_blob_storage_helper.py:224, in BlobStorageClient.check_blob_exists(self)
#     213     msg = (
#     214         "You don't have permission to alter this storage account. "
#     215         "Ensure that you have been assigned both Storage Blob Data Reader "
#     216         "and Storage Blob Data Contributor roles."
#     217     )
#     218     raise ValidationException(
#     219         message=msg,
#     220         no_personal_data_message=msg,
#     221         target=ErrorTarget.ARTIFACT,
#     222         error_category=ErrorCategory.USER_ERROR,
#     223     ) from e
# --> 224 raise e
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_artifacts\_blob_storage_helper.py:182, in BlobStorageClient.check_blob_exists(self)
#     180         exception_with_documentation.__traceback__ = e.exc_traceback
#     181         raise exception_with_documentation from e
# --> 182     raise e
#     184 metadata = properties.get("metadata")
#     186 # first check legacy folder's metadata to see if artifact is stored there
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\ai\ml\_artifacts\_blob_storage_helper.py:175, in BlobStorageClient.check_blob_exists(self)
#     172 legacy_blob_client = self.container_client.get_blob_client(blob=legacy_indicator_file)
#     174 try:
# --> 175     properties = blob_client.get_blob_properties()
#     176 except HttpResponseError as e:
#     177     if e.error_code == KEY_AUTHENTICATION_ERROR_CODE:  # pylint: disable=no-member
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\storage\blob\_blob_client.py:1370, in BlobClient.get_blob_properties(self, **kwargs)
#    1360     blob_props = self._client.blob.get_properties(
#    1361         timeout=kwargs.pop('timeout', None),
#    1362         version_id=version_id,
#    (...)   1367         cpk_info=cpk_info,
#    1368         **kwargs)
#    1369 except HttpResponseError as error:
# -> 1370     process_storage_error(error)
#    1371 blob_props.name = self.blob_name
#    1372 if isinstance(blob_props, BlobProperties):
#
# File c:\Users\yingdingwang\Documents\VENV\azamlft3.12pip\Lib\site-packages\azure\storage\blob\_shared\response_handlers.py:184, in process_storage_error(storage_error)
#     181 error.args = (error.message,)
#     182 try:
#     183     # `from None` prevents us from double printing the exception (suppresses generated layer error context)
# --> 184     exec("raise error from None")   # pylint: disable=exec-used # nosec
#     185 except SyntaxError as exc:
#     186     raise error from exc
#
# File <string>:1
#
# HttpResponseError: Operation returned an invalid status 'This request is not authorized to perform this operation.'
# ErrorCode:AuthorizationFailure

# %% [markdown]
# ## Explanation of the Above Code
#
# In order to run an AML job, we upload a set of files which contain the code we developed in the previous lab, but this time as a standalone file.  We've also added:
# * A sepearate Python file for downloading the model and tokenizer files to a fixed location on the GPU machine.  This is to ensure that we only have to download these large files ones.
# * A `main` function to the previous code that can optionally receive parameters such as batch size, learning_rate, etc.
#
# We also require an `environment`, which is just a Docker container with the proper libraries to run the standalone Python file.  This environment can be created in the *Assets -> Environments* tab on the left-hand side of the screen.
#
# When a job is submitted to AML using its SDK AML performs the following steps:
# 1.  Downloads system containers and the environment container to the cluster machine.  This may take a few minutes when done for the first time on new compute cluster machines.
#
# 2.  AML will run the standalone Python file containing the experiment code inside the environment's Docker container, while making sure it has access to an MLFLow server for tracking and all of the files in the directory specified in the command.
#
# 3.  AML will write the standard output and error streams of the run to `std_log.txt` in the working directory which can be viewed in AML under the `Jobs` tabs and clicking on the experiment name.
#
# 4.  Anything written to the `output` directory in the working directory (such as the model file or any other additional files) can be retrieved from the same place.
#
# 5.  Finally, all MLFlow metrics can be reviewed in the same place as well.
